# %%
a=13
b=15
print('a+b=',a+b)
# Out:
# a+b= 28

# %%
nombre='kelly'
edad=20
pais='china'
print('hola,me llamo',nombre)
print('tengo',edad,'años')
print('vivo en',pais)
# Out:
# hola,me llamo kelly
# tengo 20 años
# vivo en china

# %%
edad=15
if edad>=18:
    print('yes')
else:
    print('no')
# Out:
# no

# %%
for p in range(1,6):
    print(p)
# Out:
# 1
# 2
# 3
# 4
# 5
