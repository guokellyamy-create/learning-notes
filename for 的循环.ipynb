# %%
xijun=2
N=int(input('请输入几个小时'))
for i in range(N):
    xijun=xijun*3
print(N,'小时候后有细菌',xijun,'个')
# Out:
# 请输入几个小时 4
# 4 小时候后有细菌 162 个

# %%
N=10
if N>0:
    print('这是一个正数')
elif N<0:
    print('这是一个负数')
else:print('这是0')
# Out:
# 这是一个正数

# %%
score=85
if score>=90:
    print('优秀')
elif 80<=score<90:
    print('良好')
elif 60<=score<80:
    print('及格')
else:print('不合格')
# Out:
# 良好

# %%
N=input('请输入你的名字')
print('你好',N)
# Out:
# 请输入你的名字 小明
# 你好 小明

# %%
N=1
while N<=5:
    print(N)
    N=N+1
# Out:
# 1
# 2
# 3
# 4
# 5
