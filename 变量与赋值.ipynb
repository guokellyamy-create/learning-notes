# %%
glass1='奶茶'#杯子1里面放奶茶
glass2='红酒'#杯子2里面放红酒
temp=''#temp是一个临时的杯子

print(glass1)
print(glass2)

temp=glass1#把奶茶倒进临时杯子里
glass1=glass2#把红酒倒到杯子1里
glass2=temp#把奶茶从临时杯子倒进杯子2

print(glass1)
print(glass2)
# Out:
# 奶茶
# 红酒
# 红酒
# 奶茶
